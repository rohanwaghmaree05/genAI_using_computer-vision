# %% [markdown]
# Introduction to OpenCV & Image Processing

# %%
# !pip install opencv-python

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\Rohan\Desktop\OpenCV with GenAI (Prac2)\rohit sharma.webp')

img
# Out:
# array([[[194, 197, 194],
#         [191, 194, 192],
#         [188, 191, 188],
#         ...,
#         [ 52, 113,  82],
#         [ 53, 114,  83],
#         [ 53, 114,  83]],
#
#        [[194, 197, 194],
#         [191, 194, 192],
#         [188, 191, 188],
#         ...,
#         [ 51, 111,  81],
#         [ 52, 113,  82],
#         [ 52, 113,  82]],
#
#        [[195, 198, 195],
#         [192, 196, 193],
#         [189, 192, 189],
#         ...,
#         [ 49, 109,  79],
#         [ 49, 109,  79],
#         [ 49, 109,  79]],
#
#        ...,
#
#        [[ 89, 104,  81],
#         [ 89, 104,  81],
#         [ 89, 104,  81],
#         ...,
#         [255, 226, 206],
#         [255, 229, 211],
#         [255, 232, 213]],
#
#        [[ 87, 104,  81],
#         [ 87, 104,  81],
#         [ 87, 104,  81],
#         ...,
#         [252, 223, 203],
#         [249, 219, 199],
#         [247, 217, 197]],
#
#        [[ 87, 104,  81],
#         [ 87, 104,  81],
#         [ 87, 104,  81],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (444, 592, 3)

# %%
plt.imshow(img)

# %%
# Note: MATPLOTLIB = R,G,B and OPENCV = B,G,R

# %%
img
# Out:
# array([[[194, 197, 194],
#         [191, 194, 192],
#         [188, 191, 188],
#         ...,
#         [ 52, 113,  82],
#         [ 53, 114,  83],
#         [ 53, 114,  83]],
#
#        [[194, 197, 194],
#         [191, 194, 192],
#         [188, 191, 188],
#         ...,
#         [ 51, 111,  81],
#         [ 52, 113,  82],
#         [ 52, 113,  82]],
#
#        [[195, 198, 195],
#         [192, 196, 193],
#         [189, 192, 189],
#         ...,
#         [ 49, 109,  79],
#         [ 49, 109,  79],
#         [ 49, 109,  79]],
#
#        ...,
#
#        [[ 89, 104,  81],
#         [ 89, 104,  81],
#         [ 89, 104,  81],
#         ...,
#         [255, 226, 206],
#         [255, 229, 211],
#         [255, 232, 213]],
#
#        [[ 87, 104,  81],
#         [ 87, 104,  81],
#         [ 87, 104,  81],
#         ...,
#         [252, 223, 203],
#         [249, 219, 199],
#         [247, 217, 197]],
#
#        [[ 87, 104,  81],
#         [ 87, 104,  81],
#         [ 87, 104,  81],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[194, 197, 194],
#         [192, 194, 191],
#         [188, 191, 188],
#         ...,
#         [ 82, 113,  52],
#         [ 83, 114,  53],
#         [ 83, 114,  53]],
#
#        [[194, 197, 194],
#         [192, 194, 191],
#         [188, 191, 188],
#         ...,
#         [ 81, 111,  51],
#         [ 82, 113,  52],
#         [ 82, 113,  52]],
#
#        [[195, 198, 195],
#         [193, 196, 192],
#         [189, 192, 189],
#         ...,
#         [ 79, 109,  49],
#         [ 79, 109,  49],
#         [ 79, 109,  49]],
#
#        ...,
#
#        [[ 81, 104,  89],
#         [ 81, 104,  89],
#         [ 81, 104,  89],
#         ...,
#         [206, 226, 255],
#         [211, 229, 255],
#         [213, 232, 255]],
#
#        [[ 81, 104,  87],
#         [ 81, 104,  87],
#         [ 81, 104,  87],
#         ...,
#         [203, 223, 252],
#         [199, 219, 249],
#         [197, 217, 247]],
#
#        [[ 81, 104,  87],
#         [ 81, 104,  87],
#         [ 81, 104,  87],
# ...

# %%
plt.imshow(fix_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
img_grey = cv2.imread(r'C:\Users\Rohan\Desktop\OpenCV with GenAI (Prac2)\rohit sharma.webp', cv2.IMREAD_GRAYSCALE)
img_grey
# Out:
# array([[196, 193, 190, ...,  97,  98,  98],
#        [196, 193, 190, ...,  95,  97,  97],
#        [197, 195, 191, ...,  93,  93,  93],
#        ...,
#        [ 95,  95,  95, ..., 223, 227, 229],
#        [ 95,  95,  95, ..., 220, 216, 214],
#        [ 95,  95,  95, ..., 215, 217, 219]], dtype=uint8)

# %%
img_grey.shape
# Out:
# (444, 592)

# %%
img_grey.min()
# Out:
# 0

# %%
img_grey.max()
# Out:
# 255

# %%
plt.imshow(img_grey)

# %%
plt.imshow(img_grey, cmap = 'cubehelix')

# %%
plt.imshow(img_grey, cmap = 'bone')

# %%
plt.imshow(img_grey, cmap = 'PuOr')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (444, 592, 3)

# %%
fix_img_1 = cv2.resize(fix_img, (222,295))

# %%
fix_img_1.shape
# Out:
# (295, 222, 3)

# %%
w_ratio = 0.5

h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[193, 196, 193],
#         [187, 190, 187],
#         [186, 189, 185],
#         ...,
#         [ 81, 111,  51],
#         [ 82, 112,  52],
#         [ 83, 114,  53]],
#
#        [[195, 198, 194],
#         [189, 192, 189],
#         [186, 189, 185],
#         ...,
#         [ 80, 110,  50],
#         [ 79, 109,  49],
#         [ 79, 109,  49]],
#
#        [[197, 200, 197],
#         [191, 194, 191],
#         [190, 192, 189],
#         ...,
#         [ 78, 108,  48],
#         [ 79, 109,  49],
#         [ 79, 109,  49]],
#
#        ...,
#
#        [[ 81, 104,  89],
#         [ 81, 104,  89],
#         [ 81, 104,  91],
#         ...,
#         [200, 220, 245],
#         [204, 224, 251],
#         [215, 222, 247]],
#
#        [[ 81, 104,  89],
#         [ 81, 104,  89],
#         [ 81, 104,  89],
#         ...,
#         [203, 223, 250],
#         [203, 224, 252],
#         [207, 224, 250]],
#
#        [[ 81, 104,  87],
#         [ 81, 104,  87],
#         [ 81, 104,  89],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img2 = cv2.flip(fix_img_2, 0)
plt.imshow(img2)

# %%
img2 = cv2.flip(fix_img_2, 1)
plt.imshow(img2)

# %%
cv2.imwrite('new_img.webp', img2)
# Out:
# True

# %%
# end of a practical: Image Processing with OPENCV #rohanwaghmare05
